# %%
# Öncelikle tüm json dosyalarını okuyarak her birini ayrı ayrı dataframelere çevirelim

import pandas as pd
import json

def load_json_to_dataframe(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)

    questions = data["questions"]
    answers = data["answers"]

    lc_true = len(questions) > 1

    answer_column_name = file_path + " answers"

    result_rows = []

    for answer in answers:
        student_id = answer.get("id", "")
        combined_text = ""

        if lc_true:
            # Multiple questions: match each with an answer
            question_index = 1  # skip first question if it's just "id"
            for key in answer:
                if key == "id":
                    continue
                value = str(answer[key])
                if question_index < len(questions):
                    combined_text += questions[question_index] + " "
                combined_text += value + " "
                question_index += 1
        else:
            # Single question: combine all answers and prepend one question
            all_answers_combined = ""
            for key in answer:
                if key != "id":
                    all_answers_combined += str(answer[key]) + " "
            combined_text = questions[0] + " " + all_answers_combined.strip()

        result_rows.append([student_id, combined_text.strip()])

    df = pd.DataFrame(result_rows, columns=["id", answer_column_name])
    return df


json_files_sube_1 = [ "Labs/Lab1.ube_1.json", "Labs/Lab2.ube_1.json", 
                     "Labs/Lab3.ube_1.json","Labs/Lab4.ube_1.json",
                "LCs/LC1.section1.json",  "LCs/LC2.section1.json", 
                "LCs/LC3.section1.json",  "LCs/LC4.section1.json", 
                "LCs/LC5.section1.json", "LCs/LC6.section1.json",
                "LCs/LC7.section1.json", "LCs/LC8.section1.json",  
                "LCs/LC9.section1.json", "LCs/LC10.section1.json",
                "LCs/LC11.section1.json",
                "Quizzes/Quiz1.ube_1.json",  "Quizzes/Quiz2.ube_1.json",
                 "Quizzes/Quiz3.ube_1.json",  "Quizzes/Quiz4.ube_1.json" ]

json_files_sube_2 = [ "Labs/Lab1.ube_2.json", "Labs/Lab2.ube_2.json", 
                     "Labs/Lab3.ube_2.json", "Labs/Lab4.ube_2.json",
                     "LCs/LC1.section2.json", "LCs/LC2.section2.json",
                      "LCs/LC3.section2.json", "LCs/LC4.section2.json", 
                      "LCs/LC6.section2.json", "LCs/LC7.section2.json",
                      "LCs/LC8.section2.json", "LCs/LC9.section2.json",
                      "LCs/LC10.section2.json",
                     "Quizzes/Quiz1.ube_2.json", "Quizzes/Quiz2.ube_2.json",
                     "Quizzes/Quiz3.ube_2.json", "Quizzes/Quiz4.ube_2.json" ]

# %%
# Now that we can load all the json files individually, we can combine them on id

def combine_dataframes_on_id(dataframes):
    combined_df = dataframes[0]
    for df in dataframes[1:]:
        combined_df = pd.merge(combined_df, df, on="id", how="outer")
    return combined_df

# Combine all dataframes for sube 1
dataframes = []
for file in json_files_sube_1:
    df = load_json_to_dataframe(file)
    dataframes.append(df)
combined_df = combine_dataframes_on_id(dataframes)

# Display the combined dataframe
combined_df
# Out:
#          id                       Labs/Lab1.ube_1.json answers  \
# 0   4380745  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 1   7214465  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 2   1762204  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 3   9830856  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 4   8435496  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 5   8783086  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 6   4731282  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 7   6202193  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 8   8190737  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 9   7817361  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 10  2051651  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 11  6897869  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 12  1764665  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 13  6275288                                                NaN
# 14  6194008                                                NaN
# 15  8964453                                                NaN
# 16  3659398                                                NaN
# 17  4779274                                                NaN
# 18  8059049                                                NaN
# 19  5628146                                                NaN
# 20  5628146                                                NaN
# 21  6429016                                                NaN
# 22  2112376                                                NaN
# 23  5187413                                                NaN
# 24  1280995                                                NaN
# 25  6914659                                                NaN
# 26  6157698                                                NaN
# 27  9245287                                                NaN
# 28  9905145                                                NaN
# 29  5361565                                                NaN
# 30  8857652                                                NaN
#
#                          Labs/Lab2.ube_1.json answers  \
# 0   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 1   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 2   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 3   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 4   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 5   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 6   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 7   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 8   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 9   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 10  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 11  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 12  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 13  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 14  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 15  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 16  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                          Labs/Lab3.ube_1.json answers  \
# 0   Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 1   Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 2   Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 3   Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 4   Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 5   Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 6   Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 7   Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 8   Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 9   Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 10  Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 11  Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 12  Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 13  Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 14  Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 15  Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 16  Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                          Labs/Lab4.ube_1.json answers  \
# 0   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 1   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 2   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 3   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 4   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 5   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 6   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 7   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 8   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 9   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 10                                                NaN
# 11  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 12  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 13  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 14                                                NaN
# 15  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 16  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                         LCs/LC1.section1.json answers  \
# 0   Recursion nedir? Recursive bir metodun temel k...
# 1   Recursion nedir? Recursive bir metodun temel k...
# 2                                                 NaN
# 3   Recursion nedir? Recursive bir metodun temel k...
# 4   Recursion nedir? Recursive bir metodun temel k...
# 5   Recursion nedir? Recursive bir metodun temel k...
# 6   Recursion nedir? Recursive bir metodun temel k...
# 7   Recursion nedir? Recursive bir metodun temel k...
# 8   Recursion nedir? Recursive bir metodun temel k...
# 9   Recursion nedir? Recursive bir metodun temel k...
# 10  Recursion nedir? Recursive bir metodun temel k...
# 11  Recursion nedir? Recursive bir metodun temel k...
# 12  Recursion nedir? Recursive bir metodun temel k...
# 13  Recursion nedir? Recursive bir metodun temel k...
# 14  Recursion nedir? Recursive bir metodun temel k...
# 15  Recursion nedir? Recursive bir metodun temel k...
# 16  Recursion nedir? Recursive bir metodun temel k...
# 17  Recursion nedir? Recursive bir metodun temel k...
# 18  Recursion nedir? Recursive bir metodun temel k...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                         LCs/LC2.section1.json answers  \
# 0   Abstraction kavramını açıklayınız. Soyutlama, ...
# 1                                                 NaN
# 2   Abstraction kavramını açıklayınız. Sadece bizi...
# 3                                                 NaN
# 4   Abstraction kavramını açıklayınız. Kodun nasıl...
# 5   Abstraction kavramını açıklayınız. detayları g...
# 6   Abstraction kavramını açıklayınız. Belli bir k...
# 7   Abstraction kavramını açıklayınız. Soyutlama. ...
# 8   Abstraction kavramını açıklayınız. Bir nesneni...
# 9   Abstraction kavramını açıklayınız. Black Box. ...
# 10                                                NaN
# 11  Abstraction kavramını açıklayınız. Sınıflandır...
# 12  Abstraction kavramını açıklayınız. Konuyu bakı...
# 13  Abstraction kavramını açıklayınız. Herkes kend...
# 14  Abstraction kavramını açıklayınız. Soyutlama d...
# 15  Abstraction kavramını açıklayınız. Nesnenin is...
# 16  Abstraction kavramını açıklayınız. Soyutlama d...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                         LCs/LC3.section1.json answers  \
# 0   Java'da 'method binding' kavramı ne anlama gel...
# 1   Java'da 'method binding' kavramı ne anlama gel...
# 2   Java'da 'method binding' kavramı ne anlama gel...
# 3   Java'da 'method binding' kavramı ne anlama gel...
# 4   Java'da 'method binding' kavramı ne anlama gel...
# 5   Java'da 'method binding' kavramı ne anlama gel...
# 6   Java'da 'method binding' kavramı ne anlama gel...
# 7   Java'da 'method binding' kavramı ne anlama gel...
# 8   Java'da 'method binding' kavramı ne anlama gel...
# 9   Java'da 'method binding' kavramı ne anlama gel...
# 10  Java'da 'method binding' kavramı ne anlama gel...
# 11  Java'da 'method binding' kavramı ne anlama gel...
# 12  Java'da 'method binding' kavramı ne anlama gel...
# 13                                                NaN
# 14  Java'da 'method binding' kavramı ne anlama gel...
# 15  Java'da 'method binding' kavramı ne anlama gel...
# 16  Java'da 'method binding' kavramı ne anlama gel...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                         LCs/LC4.section1.json answers  \
# 0   Java'da abstract class nedir, concrete bir cla...
# 1   Java'da abstract class nedir, concrete bir cla...
# 2   Java'da abstract class nedir, concrete bir cla...
# 3   Java'da abstract class nedir, concrete bir cla...
# 4   Java'da abstract class nedir, concrete bir cla...
# 5   Java'da abstract class nedir, concrete bir cla...
# 6   Java'da abstract class nedir, concrete bir cla...
# 7   Java'da abstract class nedir, concrete bir cla...
# 8   Java'da abstract class nedir, concrete bir cla...
# 9                                                 NaN
# 10  Java'da abstract class nedir, concrete bir cla...
# 11  Java'da abstract class nedir, concrete bir cla...
# 12  Java'da abstract class nedir, concrete bir cla...
# 13  Java'da abstract class nedir, concrete bir cla...
# 14  Java'da abstract class nedir, concrete bir cla...
# 15                                                NaN
# 16  Java'da abstract class nedir, concrete bir cla...
# 17  Java'da abstract class nedir, concrete bir cla...
# 18  Java'da abstract class nedir, concrete bir cla...
# 19  Java'da abstract class nedir, concrete bir cla...
# 20  Java'da abstract class nedir, concrete bir cla...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                         LCs/LC5.section1.json answers  \
# 0   Java'da Inner class nedir, avantajları nelerdi...
# 1                                                 NaN
# 2   Java'da Inner class nedir, avantajları nelerdi...
# 3                                                 NaN
# 4   Java'da Inner class nedir, avantajları nelerdi...
# 5   Java'da Inner class nedir, avantajları nelerdi...
# 6   Java'da Inner class nedir, avantajları nelerdi...
# 7   Java'da Inner class nedir, avantajları nelerdi...
# 8   Java'da Inner class nedir, avantajları nelerdi...
# 9   Java'da Inner class nedir, avantajları nelerdi...
# 10                                                NaN
# 11  Java'da Inner class nedir, avantajları nelerdi...
# 12  Java'da Inner class nedir, avantajları nelerdi...
# 13  Java'da Inner class nedir, avantajları nelerdi...
# 14  Java'da Inner class nedir, avantajları nelerdi...
# 15                                                NaN
# 16  Java'da Inner class nedir, avantajları nelerdi...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                         LCs/LC6.section1.json answers  \
# 0                                                 NaN
# 1   Yazılım geliştirirken genelde kaç çeşit hata i...
# 2   Yazılım geliştirirken genelde kaç çeşit hata i...
# 3   Yazılım geliştirirken genelde kaç çeşit hata i...
# 4   Yazılım geliştirirken genelde kaç çeşit hata i...
# 5   Yazılım geliştirirken genelde kaç çeşit hata i...
# 6   Yazılım geliştirirken genelde kaç çeşit hata i...
# 7   Yazılım geliştirirken genelde kaç çeşit hata i...
# 8                                                 NaN
# 9   Yazılım geliştirirken genelde kaç çeşit hata i...
# 10  Yazılım geliştirirken genelde kaç çeşit hata i...
# 11  Yazılım geliştirirken genelde kaç çeşit hata i...
# 12  Yazılım geliştirirken genelde kaç çeşit hata i...
# 13  Yazılım geliştirirken genelde kaç çeşit hata i...
# 14  Yazılım geliştirirken genelde kaç çeşit hata i...
# 15  Yazılım geliştirirken genelde kaç çeşit hata i...
# 16  Yazılım geliştirirken genelde kaç çeşit hata i...
# 17  Yazılım geliştirirken genelde kaç çeşit hata i...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  Yazılım geliştirirken genelde kaç çeşit hata i...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                         LCs/LC7.section1.json answers  \
# 0   Text file ile binary file arasındaki fark nedi...
# 1   Text file ile binary file arasındaki fark nedi...
# 2   Text file ile binary file arasındaki fark nedi...
# 3   Text file ile binary file arasındaki fark nedi...
# 4   Text file ile binary file arasındaki fark nedi...
# 5                                                 NaN
# 6   Text file ile binary file arasındaki fark nedi...
# 7   Text file ile binary file arasındaki fark nedi...
# 8   Text file ile binary file arasındaki fark nedi...
# 9   Text file ile binary file arasındaki fark nedi...
# 10  Text file ile binary file arasındaki fark nedi...
# 11  Text file ile binary file arasındaki fark nedi...
# 12  Text file ile binary file arasındaki fark nedi...
# 13  Text file ile binary file arasındaki fark nedi...
# 14  Text file ile binary file arasındaki fark nedi...
# 15  Text file ile binary file arasındaki fark nedi...
# 16  Text file ile binary file arasındaki fark nedi...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  Text file ile binary file arasındaki fark nedi...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                         LCs/LC8.section1.json answers  \
# 0   What grade (A, B, C, D, or F) do you expect to...
# 1   What grade (A, B, C, D, or F) do you expect to...
# 2   What grade (A, B, C, D, or F) do you expect to...
# 3   What grade (A, B, C, D, or F) do you expect to...
# 4   What grade (A, B, C, D, or F) do you expect to...
# 5                                                 NaN
# 6   What grade (A, B, C, D, or F) do you expect to...
# 7   What grade (A, B, C, D, or F) do you expect to...
# 8   What grade (A, B, C, D, or F) do you expect to...
# 9                                                 NaN
# 10                                                NaN
# 11  What grade (A, B, C, D, or F) do you expect to...
# 12  What grade (A, B, C, D, or F) do you expect to...
# 13  What grade (A, B, C, D, or F) do you expect to...
# 14  What grade (A, B, C, D, or F) do you expect to...
# 15                                                NaN
# 16                                                NaN
# 17  What grade (A, B, C, D, or F) do you expect to...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                         LCs/LC9.section1.json answers  \
# 0   ArrayList ve LinkedList veri yapılarını kıyasl...
# 1                                                 NaN
# 2   ArrayList ve LinkedList veri yapılarını kıyasl...
# 3                                                 NaN
# 4   ArrayList ve LinkedList veri yapılarını kıyasl...
# 5   ArrayList ve LinkedList veri yapılarını kıyasl...
# 6   ArrayList ve LinkedList veri yapılarını kıyasl...
# 7                                                 NaN
# 8   ArrayList ve LinkedList veri yapılarını kıyasl...
# 9                                                 NaN
# 10                                                NaN
# 11  ArrayList ve LinkedList veri yapılarını kıyasl...
# 12                                                NaN
# 13  ArrayList ve LinkedList veri yapılarını kıyasl...
# 14  ArrayList ve LinkedList veri yapılarını kıyasl...
# 15                                                NaN
# 16                                                NaN
# 17  ArrayList ve LinkedList veri yapılarını kıyasl...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                        LCs/LC10.section1.json answers  \
# 0   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 1   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 2   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 3   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 4   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 5   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 6   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 7   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 8                                                 NaN
# 9                                                 NaN
# 10  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 11  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 12  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 13  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 14  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 15                                                NaN
# 16  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 17  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                        LCs/LC11.section1.json answers  \
# 0   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 1   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 2   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 3                                                 NaN
# 4   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 5                                                 NaN
# 6   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 7                                                 NaN
# 8                                                 NaN
# 9   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 10                                                NaN
# 11  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 12  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 13  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 14  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 19  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 20  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 21                                                NaN
# 22                                                NaN
# 23  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 24  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 25  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 26  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 27  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 28  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 29  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 30  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
#
#                      Quizzes/Quiz1.ube_1.json answers  \
# 0   Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 1   Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 2   Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 3   Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 4   Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 5   Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 6   Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 7   Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 8   Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 9   Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 10                                                NaN
# 11  Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 12  Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 13  Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 14  Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 15                                                NaN
# 16  Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                      Quizzes/Quiz2.ube_1.json answers  \
# 0   Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 1   Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 2   Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 3   Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 4   Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 5   Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 6   Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 7   Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 8   Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 9   Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 10  Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 11  Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 12  Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 13  Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 14  Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 15  Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 16  Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                      Quizzes/Quiz3.ube_1.json answers  \
# 0   Kek Üretim Boru Hattı\n\nBIL 211 - Quiz 3\n\n2...
# 1   Kek Üretim Boru Hattı\n\nBIL 211 - Quiz 3\n\n2...
# 2   Kek Üretim Boru Hattı\n\nBIL 211 - Quiz 3\n\n2...
# 3   Kek Üretim Boru Hattı\n\nBIL 211 - Quiz 3\n\n2...
# 4   Kek Üretim Boru Hattı\n\nBIL 211 - Quiz 3\n\n2...
# 5   Kek Üretim Boru Hattı\n\nBIL 211 - Quiz 3\n\n2...
# 6   Kek Üretim Boru Hattı\n\nBIL 211 - Quiz 3\n\n2...
# 7                                                 NaN
# 8                                                 NaN
# 9   Kek Üretim Boru Hattı\n\nBIL 211 - Quiz 3\n\n2...
# 10                                                NaN
# 11  Kek Üretim Boru Hattı\n\nBIL 211 - Quiz 3\n\n2...
# 12  Kek Üretim Boru Hattı\n\nBIL 211 - Quiz 3\n\n2...
# 13  Kek Üretim Boru Hattı\n\nBIL 211 - Quiz 3\n\n2...
# 14                                                NaN
# 15                                                NaN
# 16  Kek Üretim Boru Hattı\n\nBIL 211 - Quiz 3\n\n2...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                      Quizzes/Quiz4.ube_1.json answers
# 0   Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 1   Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 2   Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 3   Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 4   Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 5   Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 6   Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 7   Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 8   Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 9   Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 10                                                NaN
# 11  Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 12  Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 13  Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 14  Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 15  Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 16  Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN

# %%
combined_df.columns
# Out:
# Index(['id', 'Labs/Lab1.ube_1.json answers', 'Labs/Lab2.ube_1.json answers',
#        'Labs/Lab3.ube_1.json answers', 'Labs/Lab4.ube_1.json answers',
#        'LCs/LC1.section1.json answers', 'LCs/LC2.section1.json answers',
#        'LCs/LC3.section1.json answers', 'LCs/LC4.section1.json answers',
#        'LCs/LC5.section1.json answers', 'LCs/LC6.section1.json answers',
#        'LCs/LC7.section1.json answers', 'LCs/LC8.section1.json answers',
#        'LCs/LC9.section1.json answers', 'LCs/LC10.section1.json answers',
#        'LCs/LC11.section1.json answers', 'Quizzes/Quiz1.ube_1.json answers',
#        'Quizzes/Quiz2.ube_1.json answers', 'Quizzes/Quiz3.ube_1.json answers',
#        'Quizzes/Quiz4.ube_1.json answers'],
#       dtype='object')

# %%
# Combine all dataframes for sube 2
dataframes_sube_2 = []
for file in json_files_sube_2:
    df = load_json_to_dataframe(file)
    dataframes_sube_2.append(df)
combined_df_sube_2 = combine_dataframes_on_id(dataframes_sube_2)

# Display the combined dataframe for sube 2
combined_df_sube_2
# Out:
#          id                       Labs/Lab1.ube_2.json answers  \
# 0   6094496  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 1   7732416  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 2   4779274  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 3   2384475  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 4   5628146  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 5   2786122  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 6   9367691  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 7   6914659  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 8   2179244  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 9   6429016  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 10  6343320  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 11  4275079  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 12  7374887  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 13  5187413  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 14  6539697  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 15  9905145  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 16  5902250  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 17  4810237  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 18  4810237  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 19  9245287  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 20  4540765  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 21  6418019  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 22  4114373  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 23  3963286  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 24  1889298  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 25  6494434  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 26  8857652  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 27  2103960  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 28  8059049  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 29  5361565  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 30  3688139  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 31  6157698  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 32  1280995  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 33  9167236  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 34  4856424  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 35  9164612  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 36  5281670                                                NaN
# 37  2112376                                                NaN
# 38  8862077                                                NaN
# 39  8700334                                                NaN
# 40  1762204                                                NaN
# 41  2051651                                                NaN
#
#                          Labs/Lab2.ube_2.json answers  \
# 0   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 1   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 2   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 3   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 4   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 5   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 6                                                 NaN
# 7   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 8   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 9   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 10  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 11  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 12  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 13  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 14  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 15  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 16  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 17  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 18  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 19  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 20  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 21  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 22                                                NaN
# 23  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 24  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 25  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 26  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 27  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 28  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 29  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 30  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 31  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 32  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 33  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 34  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 35  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 36  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 37  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 38  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 39  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 40                                                NaN
# 41                                                NaN
#
#                          Labs/Lab3.ube_2.json answers  \
# 0   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 1                                                 NaN
# 2   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 3   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 4   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 5   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 6                                                 NaN
# 7   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 8   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 9   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 10  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 11                                                NaN
# 12  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 13  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 14  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 15  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 16  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 17  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 18  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 19  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 20  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 21  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 22  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 23                                                NaN
# 24                                                NaN
# 25  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 26  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 27  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 28  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 29  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 30                                                NaN
# 31  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 32  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 33  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 34  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 35  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 36  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 37                                                NaN
# 38  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 39  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 40                                                NaN
# 41                                                NaN
#
#                          Labs/Lab4.ube_2.json answers  \
# 0   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 1   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 2   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 3   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 4   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 5   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 6                                                 NaN
# 7   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 8   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 9   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 10  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 11  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 12  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 13  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 14  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 15  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 16                                                NaN
# 17  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 18  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 19  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 20  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 21  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 22  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 23  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 24  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 25  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 26  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 27  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 28  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 29  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 30  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 31  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 32  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 33  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 34                                                NaN
# 35  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 36  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 37  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 38  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
#
#                         LCs/LC1.section2.json answers  \
# 0                                                 NaN
# 1   "Recursion" kavramı nedir, kısaca açıklayınız....
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   "Recursion" kavramı nedir, kısaca açıklayınız....
# 7   "Recursion" kavramı nedir, kısaca açıklayınız....
# 8                                                 NaN
# 9   "Recursion" kavramı nedir, kısaca açıklayınız....
# 10  "Recursion" kavramı nedir, kısaca açıklayınız....
# 11                                                NaN
# 12  "Recursion" kavramı nedir, kısaca açıklayınız....
# 13  "Recursion" kavramı nedir, kısaca açıklayınız....
# 14  "Recursion" kavramı nedir, kısaca açıklayınız....
# 15                                                NaN
# 16  "Recursion" kavramı nedir, kısaca açıklayınız....
# 17  "Recursion" kavramı nedir, kısaca açıklayınız....
# 18  "Recursion" kavramı nedir, kısaca açıklayınız....
# 19  "Recursion" kavramı nedir, kısaca açıklayınız....
# 20                                                NaN
# 21  "Recursion" kavramı nedir, kısaca açıklayınız....
# 22  "Recursion" kavramı nedir, kısaca açıklayınız....
# 23  "Recursion" kavramı nedir, kısaca açıklayınız....
# 24  "Recursion" kavramı nedir, kısaca açıklayınız....
# 25  "Recursion" kavramı nedir, kısaca açıklayınız....
# 26                                                NaN
# 27  "Recursion" kavramı nedir, kısaca açıklayınız....
# 28                                                NaN
# 29  "Recursion" kavramı nedir, kısaca açıklayınız....
# 30  "Recursion" kavramı nedir, kısaca açıklayınız....
# 31                                                NaN
# 32  "Recursion" kavramı nedir, kısaca açıklayınız....
# 33                                                NaN
# 34  "Recursion" kavramı nedir, kısaca açıklayınız....
# 35                                                NaN
# 36  "Recursion" kavramı nedir, kısaca açıklayınız....
# 37                                                NaN
# 38  "Recursion" kavramı nedir, kısaca açıklayınız....
# 39                                                NaN
# 40  "Recursion" kavramı nedir, kısaca açıklayınız....
# 41                                                NaN
#
#                         LCs/LC2.section2.json answers  \
# 0   Abstraction kavramını açıklayınız. javada tanı...
# 1   Abstraction kavramını açıklayınız. Abstraction...
# 2   Abstraction kavramını açıklayınız. soyutlama, ...
# 3   Abstraction kavramını açıklayınız. İhtiyacımız...
# 4   Abstraction kavramını açıklayınız. Soyutlama, ...
# 5                                                 NaN
# 6                                                 NaN
# 7   Abstraction kavramını açıklayınız. Soyutlama a...
# 8   Abstraction kavramını açıklayınız. Gereksiz de...
# 9   Abstraction kavramını açıklayınız. Soyutluk ve...
# 10  Abstraction kavramını açıklayınız. . Dönüş tip...
# 11  Abstraction kavramını açıklayınız. ihtiyac duy...
# 12  Abstraction kavramını açıklayınız. Abstraction...
# 13  Abstraction kavramını açıklayınız. Soyutlama, ...
# 14  Abstraction kavramını açıklayınız. gerekli ver...
# 15  Abstraction kavramını açıklayınız. bize gerekt...
# 16  Abstraction kavramını açıklayınız. Hide states...
# 17  Abstraction kavramını açıklayınız. Abstraction...
# 18  Abstraction kavramını açıklayınız. Abstraction...
# 19  Abstraction kavramını açıklayınız. Kullaniciya...
# 20                                                NaN
# 21  Abstraction kavramını açıklayınız. gerekli bil...
# 22  Abstraction kavramını açıklayınız. Abstraction...
# 23  Abstraction kavramını açıklayınız. Projelerimi...
# 24  Abstraction kavramını açıklayınız. Kodun sadec...
# 25                                                NaN
# 26  Abstraction kavramını açıklayınız. Ne yaptığım...
# 27  Abstraction kavramını açıklayınız. Soyutlama g...
# 28  Abstraction kavramını açıklayınız. Black boxin...
# 29                                                NaN
# 30  Abstraction kavramını açıklayınız. Soyutlama. ...
# 31  Abstraction kavramını açıklayınız. Amacımıza u...
# 32  Abstraction kavramını açıklayınız. Yazacağımız...
# 33                                                NaN
# 34  Abstraction kavramını açıklayınız. gerekli bil...
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
#
#                         LCs/LC3.section2.json answers  \
# 0   Java'da ne zaman static binding yapılır, ne za...
# 1   Java'da ne zaman static binding yapılır, ne za...
# 2   Java'da ne zaman static binding yapılır, ne za...
# 3   Java'da ne zaman static binding yapılır, ne za...
# 4   Java'da ne zaman static binding yapılır, ne za...
# 5                                                 NaN
# 6                                                 NaN
# 7   Java'da ne zaman static binding yapılır, ne za...
# 8   Java'da ne zaman static binding yapılır, ne za...
# 9   Java'da ne zaman static binding yapılır, ne za...
# 10  Java'da ne zaman static binding yapılır, ne za...
# 11  Java'da ne zaman static binding yapılır, ne za...
# 12  Java'da ne zaman static binding yapılır, ne za...
# 13  Java'da ne zaman static binding yapılır, ne za...
# 14  Java'da ne zaman static binding yapılır, ne za...
# 15  Java'da ne zaman static binding yapılır, ne za...
# 16  Java'da ne zaman static binding yapılır, ne za...
# 17  Java'da ne zaman static binding yapılır, ne za...
# 18  Java'da ne zaman static binding yapılır, ne za...
# 19  Java'da ne zaman static binding yapılır, ne za...
# 20                                                NaN
# 21                                                NaN
# 22  Java'da ne zaman static binding yapılır, ne za...
# 23                                                NaN
# 24                                                NaN
# 25  Java'da ne zaman static binding yapılır, ne za...
# 26  Java'da ne zaman static binding yapılır, ne za...
# 27  Java'da ne zaman static binding yapılır, ne za...
# 28  Java'da ne zaman static binding yapılır, ne za...
# 29  Java'da ne zaman static binding yapılır, ne za...
# 30                                                NaN
# 31  Java'da ne zaman static binding yapılır, ne za...
# 32  Java'da ne zaman static binding yapılır, ne za...
# 33                                                NaN
# 34  Java'da ne zaman static binding yapılır, ne za...
# 35                                                NaN
# 36  Java'da ne zaman static binding yapılır, ne za...
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
#
#                         LCs/LC4.section2.json answers  \
# 0   Java'da abstract class nedir, concrete bir cla...
# 1   Java'da abstract class nedir, concrete bir cla...
# 2                                                 NaN
# 3   Java'da abstract class nedir, concrete bir cla...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Java'da abstract class nedir, concrete bir cla...
# 9   Java'da abstract class nedir, concrete bir cla...
# 10  Java'da abstract class nedir, concrete bir cla...
# 11  Java'da abstract class nedir, concrete bir cla...
# 12  Java'da abstract class nedir, concrete bir cla...
# 13                                                NaN
# 14  Java'da abstract class nedir, concrete bir cla...
# 15  Java'da abstract class nedir, concrete bir cla...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Java'da abstract class nedir, concrete bir cla...
# 20                                                NaN
# 21  Java'da abstract class nedir, concrete bir cla...
# 22  Java'da abstract class nedir, concrete bir cla...
# 23  Java'da abstract class nedir, concrete bir cla...
# 24  Java'da abstract class nedir, concrete bir cla...
# 25  Java'da abstract class nedir, concrete bir cla...
# 26  Java'da abstract class nedir, concrete bir cla...
# 27  Java'da abstract class nedir, concrete bir cla...
# 28                                                NaN
# 29  Java'da abstract class nedir, concrete bir cla...
# 30  Java'da abstract class nedir, concrete bir cla...
# 31  Java'da abstract class nedir, concrete bir cla...
# 32  Java'da abstract class nedir, concrete bir cla...
# 33                                                NaN
# 34  Java'da abstract class nedir, concrete bir cla...
# 35  Java'da abstract class nedir, concrete bir cla...
# 36  Java'da abstract class nedir, concrete bir cla...
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
#
#                         LCs/LC6.section2.json answers  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 4   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 5                                                 NaN
# 6                                                 NaN
# 7   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 8   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 9                                                 NaN
# 10  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 11  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 12  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 13  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 14  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 15  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 20                                                NaN
# 21  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 22  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 23  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 24                                                NaN
# 25                                                NaN
# 26  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 27  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 28  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 29  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 30                                                NaN
# 31  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 32  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 33                                                NaN
# 34  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 35  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 36                                                NaN
# 37  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
#
#                         LCs/LC7.section2.json answers  \
# 0                                                 NaN
# 1   Text file ile binary file arasındaki fark nedi...
# 2   Text file ile binary file arasındaki fark nedi...
# 3   Text file ile binary file arasındaki fark nedi...
# 4   Text file ile binary file arasındaki fark nedi...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  Text file ile binary file arasındaki fark nedi...
# 13  Text file ile binary file arasındaki fark nedi...
# 14  Text file ile binary file arasındaki fark nedi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  Text file ile binary file arasındaki fark nedi...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  Text file ile binary file arasındaki fark nedi...
# 27  Text file ile binary file arasındaki fark nedi...
# 28  Text file ile binary file arasındaki fark nedi...
# 29  Text file ile binary file arasındaki fark nedi...
# 30                                                NaN
# 31  Text file ile binary file arasındaki fark nedi...
# 32  Text file ile binary file arasındaki fark nedi...
# 33                                                NaN
# 34  Text file ile binary file arasındaki fark nedi...
# 35  Text file ile binary file arasındaki fark nedi...
# 36  Text file ile binary file arasındaki fark nedi...
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
#
#                         LCs/LC8.section2.json answers  \
# 0                                                 NaN
# 1   What grade (A, B, C, D, or F) do you expect to...
# 2                                                 NaN
# 3   What grade (A, B, C, D, or F) do you expect to...
# 4   What grade (A, B, C, D, or F) do you expect to...
# 5                                                 NaN
# 6                                                 NaN
# 7   What grade (A, B, C, D, or F) do you expect to...
# 8                                                 NaN
# 9                                                 NaN
# 10  What grade (A, B, C, D, or F) do you expect to...
# 11  What grade (A, B, C, D, or F) do you expect to...
# 12  What grade (A, B, C, D, or F) do you expect to...
# 13  What grade (A, B, C, D, or F) do you expect to...
# 14  What grade (A, B, C, D, or F) do you expect to...
# 15  What grade (A, B, C, D, or F) do you expect to...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  What grade (A, B, C, D, or F) do you expect to...
# 20                                                NaN
# 21  What grade (A, B, C, D, or F) do you expect to...
# 22  What grade (A, B, C, D, or F) do you expect to...
# 23  What grade (A, B, C, D, or F) do you expect to...
# 24  What grade (A, B, C, D, or F) do you expect to...
# 25                                                NaN
# 26  What grade (A, B, C, D, or F) do you expect to...
# 27  What grade (A, B, C, D, or F) do you expect to...
# 28  What grade (A, B, C, D, or F) do you expect to...
# 29  What grade (A, B, C, D, or F) do you expect to...
# 30  What grade (A, B, C, D, or F) do you expect to...
# 31  What grade (A, B, C, D, or F) do you expect to...
# 32  What grade (A, B, C, D, or F) do you expect to...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36  What grade (A, B, C, D, or F) do you expect to...
# 37  What grade (A, B, C, D, or F) do you expect to...
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41  What grade (A, B, C, D, or F) do you expect to...
#
#                         LCs/LC9.section2.json answers  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Map ve Set veri yapılarını kıyaslayınız, arala...
# 4   Map ve Set veri yapılarını kıyaslayınız, arala...
# 5                                                 NaN
# 6                                                 NaN
# 7   Map ve Set veri yapılarını kıyaslayınız, arala...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  Map ve Set veri yapılarını kıyaslayınız, arala...
# 13  Map ve Set veri yapılarını kıyaslayınız, arala...
# 14  Map ve Set veri yapılarını kıyaslayınız, arala...
# 15  Map ve Set veri yapılarını kıyaslayınız, arala...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Map ve Set veri yapılarını kıyaslayınız, arala...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  Map ve Set veri yapılarını kıyaslayınız, arala...
# 25                                                NaN
# 26                                                NaN
# 27  Map ve Set veri yapılarını kıyaslayınız, arala...
# 28  Map ve Set veri yapılarını kıyaslayınız, arala...
# 29  Map ve Set veri yapılarını kıyaslayınız, arala...
# 30  Map ve Set veri yapılarını kıyaslayınız, arala...
# 31  Map ve Set veri yapılarını kıyaslayınız, arala...
# 32  Map ve Set veri yapılarını kıyaslayınız, arala...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
#
#                        LCs/LC10.section2.json answers  \
# 0   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 1   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 2                                                 NaN
# 3   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 8                                                 NaN
# 9   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 10  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 11  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 12  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 13  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 14                                                NaN
# 15  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 20                                                NaN
# 21                                                NaN
# 22  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 23  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 24  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 25  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 26                                                NaN
# 27  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 28  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 29  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 30  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 31  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 32  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
#
#                      Quizzes/Quiz1.ube_2.json answers  \
# 0   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 1   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 2   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 3   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 4   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 5   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 6   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 7   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 8   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 9   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 10  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 11  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 12  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 13  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 14  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 15  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 16                                                NaN
# 17  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 18  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 19  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 20  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 21  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 22  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 23  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 24  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 25  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 26  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 27  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 28  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 29  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 30  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 31  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 32  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 33  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 34  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 35  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 36  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 37                                                NaN
# 38  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 39  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 40                                                NaN
# 41                                                NaN
#
#                      Quizzes/Quiz2.ube_2.json answers  \
# 0   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 1   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 2   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 3   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 4   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 5   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 6                                                 NaN
# 7   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 8   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 9   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 10  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 11  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 12  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 13  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 14  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 15  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 16  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 17  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 18  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 19  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 20  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 21  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 22  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 23                                                NaN
# 24  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 25  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 26  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 27  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 28  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 29  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 30  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 31                                                NaN
# 32  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 33  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 34  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 35  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 36  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 37  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 38  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 39  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 40                                                NaN
# 41                                                NaN
#
#                      Quizzes/Quiz3.ube_2.json answers  \
# 0                                                 NaN
# 1   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 2   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 3                                                 NaN
# 4   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 5   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 6                                                 NaN
# 7   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 8   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 9   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 10                                                NaN
# 11  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 12  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 13  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 14  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 15  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 20                                                NaN
# 21  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 22  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 23  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 24  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 25                                                NaN
# 26  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 27  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 28  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 29  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 30  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 31  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 32  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 33  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 34  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 35                                                NaN
# 36  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 37                                                NaN
# 38  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
#
#                      Quizzes/Quiz4.ube_2.json answers
# 0   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 1   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 2   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 3   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 4   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 5   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 6                                                 NaN
# 7   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 8   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 9   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 10  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 11  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 12  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 13  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 14  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 15  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 16                                                NaN
# 17  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 18  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 19  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 20  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 21  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 22  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 23                                                NaN
# 24  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 25  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 26  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 27  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 28  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 29  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 30  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 31  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 32  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 33  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 34                                                NaN
# 35  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 36  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 37  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 38  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN

# %%
# Check if there are same ids in both subes"
combined_df_sube_1_ids = set(combined_df["id"])
combined_df_sube_2_ids = set(combined_df_sube_2["id"])
common_ids = combined_df_sube_1_ids.intersection(combined_df_sube_2_ids)
print(f"Common IDs between sube 1 and sube 2: {len(common_ids)}")
# Out:
# Common IDs between sube 1 and sube 2: 15

# %%
common_ids
# Out:
# {'1280995',
#  '1762204',
#  '2051651',
#  '2112376',
#  '4779274',
#  '5187413',
#  '5361565',
#  '5628146',
#  '6157698',
#  '6429016',
#  '6914659',
#  '8059049',
#  '8857652',
#  '9245287',
#  '9905145'}

# %%
# Check how many ids are unique overall
unique_ids_sube_1 = combined_df_sube_1_ids - common_ids
unique_ids_sube_2 = combined_df_sube_2_ids - common_ids
print(f"Unique IDs in sube 1: {len(unique_ids_sube_1)}")
print(f"Unique IDs in sube 2: {len(unique_ids_sube_2)}")
# Out:
# Unique IDs in sube 1: 15
# Unique IDs in sube 2: 26

# %%
# We know from the csv files that sube 1 has 16 people and sube 2 has 45 so all the common ids should be moved to sube 2 side.
# We need to move the common ids from sube 1 to sube 2
# We cant just drop the common ids from sube 1 because we need to keep the answers of those ids in sube 2
# We need to create new arrays for common id students to gather their answers from sube 1 and sube 2 so we can add them to sube 2 properly
# After that we will change all NaN values to empty strings in the combined dataframe
# Then we can add the questions to respective answers and combine all the data for each student
# Then we can use a vectorizer to convert the answers to vectors
# Which we can use to train a model

# Add answers earlier the questions ni both classes are different so we need to add the questions for context

# %%
test_Students = pd.read_csv("processed_test_student.csv")
train_Students = pd.read_csv("processed_train_student.csv")

# %%
# Check if there are matching ids in both test and train students
test_ids = set(test_Students["UID"])
train_ids = set(train_Students["UID"])
common_test_train_ids = test_ids.intersection(train_ids)
print(f"Common IDs between test and train students: {common_test_train_ids}")
# Out:
# Common IDs between test and train students: {2384475}

# %%
# The student with UID 2384475 is in both test and train students in the csv files that have been provided.
# I will not be including it in the train dataset because it is data leakage.

# %%
for item in test_ids:
    if str(item) in common_ids:
        print(item)
# Out:
# 2051651
# 6914659
# 1280995
# 4779274
# 5187413

# %%
for item in train_ids:
    if str(item) in common_ids:
        print(item)
# Out:
# 6157698
# 1762204
# 5361565
# 8059049
# 8857652
# 6429016
# 9245287
# 5628146
# 2112376
# 9905145

# %%
# Get the rows from combined_df and combined_df_sube_2 where the id is in common_ids
common_rows_sube_1 = combined_df[combined_df["id"].isin(common_ids)]
common_rows_sube_2 = combined_df_sube_2[combined_df_sube_2["id"].isin(common_ids)]

# %%
# Remove the common ids from combined_df and combined_df_sube_2

combined_df = combined_df[~combined_df["id"].isin(common_ids)]
combined_df_sube_2 = combined_df_sube_2[~combined_df_sube_2["id"].isin(common_ids)]

# %%
# Sort both common rows by id
common_rows_sube_1 = common_rows_sube_1.sort_values(by="id")
common_rows_sube_2 = common_rows_sube_2.sort_values(by="id")
# Reset the index of both common rows
common_rows_sube_1 = common_rows_sube_1.reset_index(drop=True)
common_rows_sube_2 = common_rows_sube_2.reset_index(drop=True)

# %%
common_rows_sube_1
# Out:
#          id                       Labs/Lab1.ube_1.json answers  \
# 0   1280995                                                NaN
# 1   1762204  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 2   2051651  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 3   2112376                                                NaN
# 4   4779274                                                NaN
# 5   5187413                                                NaN
# 6   5361565                                                NaN
# 7   5628146                                                NaN
# 8   5628146                                                NaN
# 9   6157698                                                NaN
# 10  6429016                                                NaN
# 11  6914659                                                NaN
# 12  8059049                                                NaN
# 13  8857652                                                NaN
# 14  9245287                                                NaN
# 15  9905145                                                NaN
#
#                          Labs/Lab2.ube_1.json answers  \
# 0                                                 NaN
# 1   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 2   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                          Labs/Lab3.ube_1.json answers  \
# 0                                                 NaN
# 1   Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 2   Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                          Labs/Lab4.ube_1.json answers  \
# 0                                                 NaN
# 1   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                         LCs/LC1.section1.json answers  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Recursion nedir? Recursive bir metodun temel k...
# 3                                                 NaN
# 4   Recursion nedir? Recursive bir metodun temel k...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  Recursion nedir? Recursive bir metodun temel k...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                         LCs/LC2.section1.json answers  \
# 0                                                 NaN
# 1   Abstraction kavramını açıklayınız. Sadece bizi...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                         LCs/LC3.section1.json answers  \
# 0                                                 NaN
# 1   Java'da 'method binding' kavramı ne anlama gel...
# 2   Java'da 'method binding' kavramı ne anlama gel...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                         LCs/LC4.section1.json answers  \
# 0                                                 NaN
# 1   Java'da abstract class nedir, concrete bir cla...
# 2   Java'da abstract class nedir, concrete bir cla...
# 3                                                 NaN
# 4   Java'da abstract class nedir, concrete bir cla...
# 5                                                 NaN
# 6                                                 NaN
# 7   Java'da abstract class nedir, concrete bir cla...
# 8   Java'da abstract class nedir, concrete bir cla...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  Java'da abstract class nedir, concrete bir cla...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                         LCs/LC5.section1.json answers  \
# 0                                                 NaN
# 1   Java'da Inner class nedir, avantajları nelerdi...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                         LCs/LC6.section1.json answers  \
# 0                                                 NaN
# 1   Yazılım geliştirirken genelde kaç çeşit hata i...
# 2   Yazılım geliştirirken genelde kaç çeşit hata i...
# 3                                                 NaN
# 4   Yazılım geliştirirken genelde kaç çeşit hata i...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Yazılım geliştirirken genelde kaç çeşit hata i...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                         LCs/LC7.section1.json answers  \
# 0                                                 NaN
# 1   Text file ile binary file arasındaki fark nedi...
# 2   Text file ile binary file arasındaki fark nedi...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Text file ile binary file arasındaki fark nedi...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                         LCs/LC8.section1.json answers  \
# 0                                                 NaN
# 1   What grade (A, B, C, D, or F) do you expect to...
# 2                                                 NaN
# 3                                                 NaN
# 4   What grade (A, B, C, D, or F) do you expect to...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                         LCs/LC9.section1.json answers  \
# 0                                                 NaN
# 1   ArrayList ve LinkedList veri yapılarını kıyasl...
# 2                                                 NaN
# 3                                                 NaN
# 4   ArrayList ve LinkedList veri yapılarını kıyasl...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                        LCs/LC10.section1.json answers  \
# 0                                                 NaN
# 1   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 2   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 3   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 4   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                        LCs/LC11.section1.json answers  \
# 0   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 1   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 6   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 7   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 8   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 9   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 10                                                NaN
# 11  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 12  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 13  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 14  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 15  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
#
#                      Quizzes/Quiz1.ube_1.json answers  \
# 0                                                 NaN
# 1   Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                      Quizzes/Quiz2.ube_1.json answers  \
# 0                                                 NaN
# 1   Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 2   Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                      Quizzes/Quiz3.ube_1.json answers  \
# 0                                                 NaN
# 1   Kek Üretim Boru Hattı\n\nBIL 211 - Quiz 3\n\n2...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                      Quizzes/Quiz4.ube_1.json answers
# 0                                                 NaN
# 1   Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN

# %%
# Student with the id 5628146 is counted twice so we will remove it once

common_rows_sube_1 = common_rows_sube_1.drop(8)
common_rows_sube_1 = common_rows_sube_1.reset_index(drop=True)

# %%
common_rows_sube_2
# Out:
#          id                       Labs/Lab1.ube_2.json answers  \
# 0   1280995  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 1   1762204                                                NaN
# 2   2051651                                                NaN
# 3   2112376                                                NaN
# 4   4779274  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 5   5187413  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 6   5361565  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 7   5628146  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 8   6157698  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 9   6429016  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 10  6914659  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 11  8059049  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 12  8857652  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 13  9245287  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 14  9905145  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
#
#                          Labs/Lab2.ube_2.json answers  \
# 0   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 1                                                 NaN
# 2                                                 NaN
# 3   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 4   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 5   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 6   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 7   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 8   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 9   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 10  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 11  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 12  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 13  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 14  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
#
#                          Labs/Lab3.ube_2.json answers  \
# 0   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 5   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 6   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 7   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 8   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 9   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 10  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 11  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 12  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 13  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 14  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
#
#                          Labs/Lab4.ube_2.json answers  \
# 0   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 1                                                 NaN
# 2                                                 NaN
# 3   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 4   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 5   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 6   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 7   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 8   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 9   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 10  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 11  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 12  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 13  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 14  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
#
#                         LCs/LC1.section2.json answers  \
# 0   "Recursion" kavramı nedir, kısaca açıklayınız....
# 1   "Recursion" kavramı nedir, kısaca açıklayınız....
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   "Recursion" kavramı nedir, kısaca açıklayınız....
# 6   "Recursion" kavramı nedir, kısaca açıklayınız....
# 7                                                 NaN
# 8                                                 NaN
# 9   "Recursion" kavramı nedir, kısaca açıklayınız....
# 10  "Recursion" kavramı nedir, kısaca açıklayınız....
# 11                                                NaN
# 12                                                NaN
# 13  "Recursion" kavramı nedir, kısaca açıklayınız....
# 14                                                NaN
#
#                         LCs/LC2.section2.json answers  \
# 0   Abstraction kavramını açıklayınız. Yazacağımız...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Abstraction kavramını açıklayınız. soyutlama, ...
# 5   Abstraction kavramını açıklayınız. Soyutlama, ...
# 6                                                 NaN
# 7   Abstraction kavramını açıklayınız. Soyutlama, ...
# 8   Abstraction kavramını açıklayınız. Amacımıza u...
# 9   Abstraction kavramını açıklayınız. Soyutluk ve...
# 10  Abstraction kavramını açıklayınız. Soyutlama a...
# 11  Abstraction kavramını açıklayınız. Black boxin...
# 12  Abstraction kavramını açıklayınız. Ne yaptığım...
# 13  Abstraction kavramını açıklayınız. Kullaniciya...
# 14  Abstraction kavramını açıklayınız. bize gerekt...
#
#                         LCs/LC3.section2.json answers  \
# 0   Java'da ne zaman static binding yapılır, ne za...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Java'da ne zaman static binding yapılır, ne za...
# 5   Java'da ne zaman static binding yapılır, ne za...
# 6   Java'da ne zaman static binding yapılır, ne za...
# 7   Java'da ne zaman static binding yapılır, ne za...
# 8   Java'da ne zaman static binding yapılır, ne za...
# 9   Java'da ne zaman static binding yapılır, ne za...
# 10  Java'da ne zaman static binding yapılır, ne za...
# 11  Java'da ne zaman static binding yapılır, ne za...
# 12  Java'da ne zaman static binding yapılır, ne za...
# 13  Java'da ne zaman static binding yapılır, ne za...
# 14  Java'da ne zaman static binding yapılır, ne za...
#
#                         LCs/LC4.section2.json answers  \
# 0   Java'da abstract class nedir, concrete bir cla...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   Java'da abstract class nedir, concrete bir cla...
# 7                                                 NaN
# 8   Java'da abstract class nedir, concrete bir cla...
# 9   Java'da abstract class nedir, concrete bir cla...
# 10                                                NaN
# 11                                                NaN
# 12  Java'da abstract class nedir, concrete bir cla...
# 13  Java'da abstract class nedir, concrete bir cla...
# 14  Java'da abstract class nedir, concrete bir cla...
#
#                         LCs/LC6.section2.json answers  \
# 0   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 1                                                 NaN
# 2                                                 NaN
# 3   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 4                                                 NaN
# 5   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 6   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 7   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 8   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 9                                                 NaN
# 10  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 11  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 12  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 13  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 14  Java'da Exceptionlar kaç çeşittir, her çeşit i...
#
#                         LCs/LC7.section2.json answers  \
# 0   Text file ile binary file arasındaki fark nedi...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Text file ile binary file arasındaki fark nedi...
# 5   Text file ile binary file arasındaki fark nedi...
# 6   Text file ile binary file arasındaki fark nedi...
# 7   Text file ile binary file arasındaki fark nedi...
# 8   Text file ile binary file arasındaki fark nedi...
# 9                                                 NaN
# 10                                                NaN
# 11  Text file ile binary file arasındaki fark nedi...
# 12  Text file ile binary file arasındaki fark nedi...
# 13                                                NaN
# 14                                                NaN
#
#                         LCs/LC8.section2.json answers  \
# 0   What grade (A, B, C, D, or F) do you expect to...
# 1                                                 NaN
# 2   What grade (A, B, C, D, or F) do you expect to...
# 3   What grade (A, B, C, D, or F) do you expect to...
# 4                                                 NaN
# 5   What grade (A, B, C, D, or F) do you expect to...
# 6   What grade (A, B, C, D, or F) do you expect to...
# 7   What grade (A, B, C, D, or F) do you expect to...
# 8   What grade (A, B, C, D, or F) do you expect to...
# 9                                                 NaN
# 10  What grade (A, B, C, D, or F) do you expect to...
# 11  What grade (A, B, C, D, or F) do you expect to...
# 12  What grade (A, B, C, D, or F) do you expect to...
# 13  What grade (A, B, C, D, or F) do you expect to...
# 14  What grade (A, B, C, D, or F) do you expect to...
#
#                         LCs/LC9.section2.json answers  \
# 0   Map ve Set veri yapılarını kıyaslayınız, arala...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Map ve Set veri yapılarını kıyaslayınız, arala...
# 6   Map ve Set veri yapılarını kıyaslayınız, arala...
# 7   Map ve Set veri yapılarını kıyaslayınız, arala...
# 8   Map ve Set veri yapılarını kıyaslayınız, arala...
# 9                                                 NaN
# 10  Map ve Set veri yapılarını kıyaslayınız, arala...
# 11  Map ve Set veri yapılarını kıyaslayınız, arala...
# 12                                                NaN
# 13  Map ve Set veri yapılarını kıyaslayınız, arala...
# 14  Map ve Set veri yapılarını kıyaslayınız, arala...
#
#                        LCs/LC10.section2.json answers  \
# 0   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 6   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 7                                                 NaN
# 8   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 9   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 10  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 11  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 12                                                NaN
# 13  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 14  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
#
#                      Quizzes/Quiz1.ube_2.json answers  \
# 0   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 5   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 6   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 7   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 8   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 9   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 10  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 11  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 12  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 13  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 14  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
#
#                      Quizzes/Quiz2.ube_2.json answers  \
# 0   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 1                                                 NaN
# 2                                                 NaN
# 3   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 4   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 5   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 6   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 7   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 8                                                 NaN
# 9   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 10  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 11  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 12  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 13  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 14  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
#
#                      Quizzes/Quiz3.ube_2.json answers  \
# 0   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 5   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 6   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 7   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 8   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 9   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 10  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 11  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 12  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 13  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 14  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
#
#                      Quizzes/Quiz4.ube_2.json answers
# 0   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 1                                                 NaN
# 2                                                 NaN
# 3   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 4   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 5   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 6   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 7   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 8   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 9   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 10  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 11  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 12  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 13  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 14  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...

# %% [markdown]
# From now on manual changes need to be made regarding column differences in both datasets

# %%
# We need to account for the fact that the sube2 did not take LC5 so the length is shorter than sube 1
# So we will add a column to common_rows_sube_2 with empty strings for LC5

common_rows_sube_2["LCs/LC5.section2.json answers"] = float('nan')

# We need to move the columns so that LC5 is after LC4
cols = common_rows_sube_2.columns.tolist()
lc6_index = cols.index("LCs/LC6.section2.json answers")
cols.insert(lc6_index, cols.pop(cols.index("LCs/LC5.section2.json answers")))
common_rows_sube_2 = common_rows_sube_2[cols]

# We also need to do this for LC11

common_rows_sube_2["LCs/LC11.section2.json answers"] = float('nan')

# Move LC11 to the end
cols = common_rows_sube_2.columns.tolist()
quiz1_index = cols.index("Quizzes/Quiz1.ube_2.json answers")
cols.insert(quiz1_index, cols.pop(cols.index("LCs/LC11.section2.json answers")))
common_rows_sube_2 = common_rows_sube_2[cols]
# Out:
# C:\Users\Talha\AppData\Local\Temp\ipykernel_20252\2803330820.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   common_rows_sube_2["LCs/LC11.section2.json answers"] = float('nan')

# %%
common_rows_sube_2
# Out:
#          id                       Labs/Lab1.ube_2.json answers  \
# 0   1280995  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 1   1762204                                                NaN
# 2   2051651                                                NaN
# 3   2112376                                                NaN
# 4   4779274  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 5   5187413  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 6   5361565  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 7   5628146  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 8   6157698  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 9   6429016  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 10  6914659  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 11  8059049  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 12  8857652  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 13  9245287  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 14  9905145  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
#
#                          Labs/Lab2.ube_2.json answers  \
# 0   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 1                                                 NaN
# 2                                                 NaN
# 3   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 4   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 5   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 6   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 7   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 8   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 9   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 10  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 11  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 12  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 13  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 14  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
#
#                          Labs/Lab3.ube_2.json answers  \
# 0   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 5   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 6   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 7   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 8   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 9   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 10  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 11  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 12  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 13  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 14  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
#
#                          Labs/Lab4.ube_2.json answers  \
# 0   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 1                                                 NaN
# 2                                                 NaN
# 3   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 4   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 5   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 6   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 7   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 8   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 9   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 10  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 11  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 12  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 13  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 14  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
#
#                         LCs/LC1.section2.json answers  \
# 0   "Recursion" kavramı nedir, kısaca açıklayınız....
# 1   "Recursion" kavramı nedir, kısaca açıklayınız....
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   "Recursion" kavramı nedir, kısaca açıklayınız....
# 6   "Recursion" kavramı nedir, kısaca açıklayınız....
# 7                                                 NaN
# 8                                                 NaN
# 9   "Recursion" kavramı nedir, kısaca açıklayınız....
# 10  "Recursion" kavramı nedir, kısaca açıklayınız....
# 11                                                NaN
# 12                                                NaN
# 13  "Recursion" kavramı nedir, kısaca açıklayınız....
# 14                                                NaN
#
#                         LCs/LC2.section2.json answers  \
# 0   Abstraction kavramını açıklayınız. Yazacağımız...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Abstraction kavramını açıklayınız. soyutlama, ...
# 5   Abstraction kavramını açıklayınız. Soyutlama, ...
# 6                                                 NaN
# 7   Abstraction kavramını açıklayınız. Soyutlama, ...
# 8   Abstraction kavramını açıklayınız. Amacımıza u...
# 9   Abstraction kavramını açıklayınız. Soyutluk ve...
# 10  Abstraction kavramını açıklayınız. Soyutlama a...
# 11  Abstraction kavramını açıklayınız. Black boxin...
# 12  Abstraction kavramını açıklayınız. Ne yaptığım...
# 13  Abstraction kavramını açıklayınız. Kullaniciya...
# 14  Abstraction kavramını açıklayınız. bize gerekt...
#
#                         LCs/LC3.section2.json answers  \
# 0   Java'da ne zaman static binding yapılır, ne za...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Java'da ne zaman static binding yapılır, ne za...
# 5   Java'da ne zaman static binding yapılır, ne za...
# 6   Java'da ne zaman static binding yapılır, ne za...
# 7   Java'da ne zaman static binding yapılır, ne za...
# 8   Java'da ne zaman static binding yapılır, ne za...
# 9   Java'da ne zaman static binding yapılır, ne za...
# 10  Java'da ne zaman static binding yapılır, ne za...
# 11  Java'da ne zaman static binding yapılır, ne za...
# 12  Java'da ne zaman static binding yapılır, ne za...
# 13  Java'da ne zaman static binding yapılır, ne za...
# 14  Java'da ne zaman static binding yapılır, ne za...
#
#                         LCs/LC4.section2.json answers  \
# 0   Java'da abstract class nedir, concrete bir cla...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   Java'da abstract class nedir, concrete bir cla...
# 7                                                 NaN
# 8   Java'da abstract class nedir, concrete bir cla...
# 9   Java'da abstract class nedir, concrete bir cla...
# 10                                                NaN
# 11                                                NaN
# 12  Java'da abstract class nedir, concrete bir cla...
# 13  Java'da abstract class nedir, concrete bir cla...
# 14  Java'da abstract class nedir, concrete bir cla...
#
#     LCs/LC5.section2.json answers  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
#
#                         LCs/LC6.section2.json answers  \
# 0   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 1                                                 NaN
# 2                                                 NaN
# 3   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 4                                                 NaN
# 5   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 6   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 7   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 8   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 9                                                 NaN
# 10  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 11  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 12  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 13  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 14  Java'da Exceptionlar kaç çeşittir, her çeşit i...
#
#                         LCs/LC7.section2.json answers  \
# 0   Text file ile binary file arasındaki fark nedi...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Text file ile binary file arasındaki fark nedi...
# 5   Text file ile binary file arasındaki fark nedi...
# 6   Text file ile binary file arasındaki fark nedi...
# 7   Text file ile binary file arasındaki fark nedi...
# 8   Text file ile binary file arasındaki fark nedi...
# 9                                                 NaN
# 10                                                NaN
# 11  Text file ile binary file arasındaki fark nedi...
# 12  Text file ile binary file arasındaki fark nedi...
# 13                                                NaN
# 14                                                NaN
#
#                         LCs/LC8.section2.json answers  \
# 0   What grade (A, B, C, D, or F) do you expect to...
# 1                                                 NaN
# 2   What grade (A, B, C, D, or F) do you expect to...
# 3   What grade (A, B, C, D, or F) do you expect to...
# 4                                                 NaN
# 5   What grade (A, B, C, D, or F) do you expect to...
# 6   What grade (A, B, C, D, or F) do you expect to...
# 7   What grade (A, B, C, D, or F) do you expect to...
# 8   What grade (A, B, C, D, or F) do you expect to...
# 9                                                 NaN
# 10  What grade (A, B, C, D, or F) do you expect to...
# 11  What grade (A, B, C, D, or F) do you expect to...
# 12  What grade (A, B, C, D, or F) do you expect to...
# 13  What grade (A, B, C, D, or F) do you expect to...
# 14  What grade (A, B, C, D, or F) do you expect to...
#
#                         LCs/LC9.section2.json answers  \
# 0   Map ve Set veri yapılarını kıyaslayınız, arala...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Map ve Set veri yapılarını kıyaslayınız, arala...
# 6   Map ve Set veri yapılarını kıyaslayınız, arala...
# 7   Map ve Set veri yapılarını kıyaslayınız, arala...
# 8   Map ve Set veri yapılarını kıyaslayınız, arala...
# 9                                                 NaN
# 10  Map ve Set veri yapılarını kıyaslayınız, arala...
# 11  Map ve Set veri yapılarını kıyaslayınız, arala...
# 12                                                NaN
# 13  Map ve Set veri yapılarını kıyaslayınız, arala...
# 14  Map ve Set veri yapılarını kıyaslayınız, arala...
#
#                        LCs/LC10.section2.json answers  \
# 0   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 6   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 7                                                 NaN
# 8   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 9   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 10  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 11  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 12                                                NaN
# 13  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 14  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
#
#     LCs/LC11.section2.json answers  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
#
#                      Quizzes/Quiz1.ube_2.json answers  \
# 0   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 5   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 6   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 7   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 8   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 9   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 10  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 11  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 12  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 13  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 14  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
#
#                      Quizzes/Quiz2.ube_2.json answers  \
# 0   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 1                                                 NaN
# 2                                                 NaN
# 3   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 4   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 5   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 6   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 7   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 8                                                 NaN
# 9   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 10  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 11  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 12  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 13  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 14  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
#
#                      Quizzes/Quiz3.ube_2.json answers  \
# 0   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 5   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 6   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 7   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 8   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 9   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 10  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 11  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 12  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 13  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 14  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
#
#                      Quizzes/Quiz4.ube_2.json answers
# 0   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 1                                                 NaN
# 2                                                 NaN
# 3   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 4   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 5   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 6   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 7   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 8   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 9   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 10  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 11  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 12  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 13  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 14  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...

# %%
# Get the rows as lists from both common rows
common_rows_sube_1_list = common_rows_sube_1.values.tolist()
common_rows_sube_2_list = common_rows_sube_2.values.tolist()

# %%
# Compare each row in common_rows_sube_1_list with the corresponding row in common_rows_sube_2_list
# If an answer is nan in one of them and not in the other, we will take the answer from the one that has it
# If both are nan, we will leave it as nan
# Create a new list to store the combined rows

# We need to account for the fact that there is an unused row 

common_combined_rows = []
for i in range(len(common_rows_sube_1_list)):
    row_1 = common_rows_sube_1_list[i]
    row_2 = common_rows_sube_2_list[i]
    
    combined_row = [row_1[0]]  # Start with the id
    
    for j in range(1, len(row_1)):
        if pd.isna(row_1[j]) and not pd.isna(row_2[j]):
            combined_row.append(row_2[j])
        elif not pd.isna(row_1[j]) and pd.isna(row_2[j]):
            combined_row.append(row_1[j])
        else:
            combined_row.append(row_1[j])  # Both are NaN or both have values, take from sube 1
    
    common_combined_rows.append(combined_row)

# %%
# Turn the combined rows into a DataFrame
common_combined_df = pd.DataFrame(common_combined_rows, columns=common_rows_sube_1.columns)
common_combined_df
# Out:
#          id                       Labs/Lab1.ube_1.json answers  \
# 0   1280995  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 1   1762204  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 2   2051651  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 3   2112376                                                NaN
# 4   4779274  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 5   5187413  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 6   5361565  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 7   5628146  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 8   6157698  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 9   6429016  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 10  6914659  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 11  8059049  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 12  8857652  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 13  9245287  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 14  9905145  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
#
#                          Labs/Lab2.ube_1.json answers  \
# 0   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 1   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 2   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 3   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 4   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 5   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 6   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 7   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 8   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 9   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 10  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 11  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 12  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 13  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
# 14  Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratuv...
#
#                          Labs/Lab3.ube_1.json answers  \
# 0   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 1   Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 2   Metin Karşılaştırıcı\nBIL 211 - Lab 3\n20 Şuba...
# 3                                                 NaN
# 4   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 5   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 6   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 7   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 8   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 9   Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 10  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 11  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 12  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 13  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
# 14  Kelime Sayıcı\nBIL 211 - Lab 3\n20 Şubat 2025\...
#
#                          Labs/Lab4.ube_1.json answers  \
# 0   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 1   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 2                                                 NaN
# 3   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 4   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 5   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 6   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 7   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 8   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 9   Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 10  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 11  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 12  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 13  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
# 14  Generic\n\n1)  Envanter Yönetim Sistemi\n\nBu ...
#
#                         LCs/LC1.section1.json answers  \
# 0   "Recursion" kavramı nedir, kısaca açıklayınız....
# 1   "Recursion" kavramı nedir, kısaca açıklayınız....
# 2   Recursion nedir? Recursive bir metodun temel k...
# 3                                                 NaN
# 4   Recursion nedir? Recursive bir metodun temel k...
# 5   "Recursion" kavramı nedir, kısaca açıklayınız....
# 6   "Recursion" kavramı nedir, kısaca açıklayınız....
# 7                                                 NaN
# 8                                                 NaN
# 9   "Recursion" kavramı nedir, kısaca açıklayınız....
# 10  "Recursion" kavramı nedir, kısaca açıklayınız....
# 11  Recursion nedir? Recursive bir metodun temel k...
# 12                                                NaN
# 13  "Recursion" kavramı nedir, kısaca açıklayınız....
# 14                                                NaN
#
#                         LCs/LC2.section1.json answers  \
# 0   Abstraction kavramını açıklayınız. Yazacağımız...
# 1   Abstraction kavramını açıklayınız. Sadece bizi...
# 2                                                 NaN
# 3                                                 NaN
# 4   Abstraction kavramını açıklayınız. soyutlama, ...
# 5   Abstraction kavramını açıklayınız. Soyutlama, ...
# 6                                                 NaN
# 7   Abstraction kavramını açıklayınız. Soyutlama, ...
# 8   Abstraction kavramını açıklayınız. Amacımıza u...
# 9   Abstraction kavramını açıklayınız. Soyutluk ve...
# 10  Abstraction kavramını açıklayınız. Soyutlama a...
# 11  Abstraction kavramını açıklayınız. Black boxin...
# 12  Abstraction kavramını açıklayınız. Ne yaptığım...
# 13  Abstraction kavramını açıklayınız. Kullaniciya...
# 14  Abstraction kavramını açıklayınız. bize gerekt...
#
#                         LCs/LC3.section1.json answers  \
# 0   Java'da ne zaman static binding yapılır, ne za...
# 1   Java'da 'method binding' kavramı ne anlama gel...
# 2   Java'da 'method binding' kavramı ne anlama gel...
# 3                                                 NaN
# 4   Java'da ne zaman static binding yapılır, ne za...
# 5   Java'da ne zaman static binding yapılır, ne za...
# 6   Java'da ne zaman static binding yapılır, ne za...
# 7   Java'da ne zaman static binding yapılır, ne za...
# 8   Java'da ne zaman static binding yapılır, ne za...
# 9   Java'da ne zaman static binding yapılır, ne za...
# 10  Java'da ne zaman static binding yapılır, ne za...
# 11  Java'da ne zaman static binding yapılır, ne za...
# 12  Java'da ne zaman static binding yapılır, ne za...
# 13  Java'da ne zaman static binding yapılır, ne za...
# 14  Java'da ne zaman static binding yapılır, ne za...
#
#                         LCs/LC4.section1.json answers  \
# 0   Java'da abstract class nedir, concrete bir cla...
# 1   Java'da abstract class nedir, concrete bir cla...
# 2   Java'da abstract class nedir, concrete bir cla...
# 3                                                 NaN
# 4   Java'da abstract class nedir, concrete bir cla...
# 5                                                 NaN
# 6   Java'da abstract class nedir, concrete bir cla...
# 7   Java'da abstract class nedir, concrete bir cla...
# 8   Java'da abstract class nedir, concrete bir cla...
# 9   Java'da abstract class nedir, concrete bir cla...
# 10                                                NaN
# 11  Java'da abstract class nedir, concrete bir cla...
# 12  Java'da abstract class nedir, concrete bir cla...
# 13  Java'da abstract class nedir, concrete bir cla...
# 14  Java'da abstract class nedir, concrete bir cla...
#
#                         LCs/LC5.section1.json answers  \
# 0                                                 NaN
# 1   Java'da Inner class nedir, avantajları nelerdi...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                         LCs/LC6.section1.json answers  \
# 0   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 1   Yazılım geliştirirken genelde kaç çeşit hata i...
# 2   Yazılım geliştirirken genelde kaç çeşit hata i...
# 3   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 4   Yazılım geliştirirken genelde kaç çeşit hata i...
# 5   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 6   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 7   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 8   Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 9   Yazılım geliştirirken genelde kaç çeşit hata i...
# 10  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 11  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 12  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 13  Java'da Exceptionlar kaç çeşittir, her çeşit i...
# 14  Java'da Exceptionlar kaç çeşittir, her çeşit i...
#
#                         LCs/LC7.section1.json answers  \
# 0   Text file ile binary file arasındaki fark nedi...
# 1   Text file ile binary file arasındaki fark nedi...
# 2   Text file ile binary file arasındaki fark nedi...
# 3                                                 NaN
# 4   Text file ile binary file arasındaki fark nedi...
# 5   Text file ile binary file arasındaki fark nedi...
# 6   Text file ile binary file arasındaki fark nedi...
# 7   Text file ile binary file arasındaki fark nedi...
# 8   Text file ile binary file arasındaki fark nedi...
# 9   Text file ile binary file arasındaki fark nedi...
# 10                                                NaN
# 11  Text file ile binary file arasındaki fark nedi...
# 12  Text file ile binary file arasındaki fark nedi...
# 13                                                NaN
# 14                                                NaN
#
#                         LCs/LC8.section1.json answers  \
# 0   What grade (A, B, C, D, or F) do you expect to...
# 1   What grade (A, B, C, D, or F) do you expect to...
# 2   What grade (A, B, C, D, or F) do you expect to...
# 3   What grade (A, B, C, D, or F) do you expect to...
# 4   What grade (A, B, C, D, or F) do you expect to...
# 5   What grade (A, B, C, D, or F) do you expect to...
# 6   What grade (A, B, C, D, or F) do you expect to...
# 7   What grade (A, B, C, D, or F) do you expect to...
# 8   What grade (A, B, C, D, or F) do you expect to...
# 9                                                 NaN
# 10  What grade (A, B, C, D, or F) do you expect to...
# 11  What grade (A, B, C, D, or F) do you expect to...
# 12  What grade (A, B, C, D, or F) do you expect to...
# 13  What grade (A, B, C, D, or F) do you expect to...
# 14  What grade (A, B, C, D, or F) do you expect to...
#
#                         LCs/LC9.section1.json answers  \
# 0   Map ve Set veri yapılarını kıyaslayınız, arala...
# 1   ArrayList ve LinkedList veri yapılarını kıyasl...
# 2                                                 NaN
# 3                                                 NaN
# 4   ArrayList ve LinkedList veri yapılarını kıyasl...
# 5   Map ve Set veri yapılarını kıyaslayınız, arala...
# 6   Map ve Set veri yapılarını kıyaslayınız, arala...
# 7   Map ve Set veri yapılarını kıyaslayınız, arala...
# 8   Map ve Set veri yapılarını kıyaslayınız, arala...
# 9                                                 NaN
# 10  Map ve Set veri yapılarını kıyaslayınız, arala...
# 11  Map ve Set veri yapılarını kıyaslayınız, arala...
# 12                                                NaN
# 13  Map ve Set veri yapılarını kıyaslayınız, arala...
# 14  Map ve Set veri yapılarını kıyaslayınız, arala...
#
#                        LCs/LC10.section1.json answers  \
# 0   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 1   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 2   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 3   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 4   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 5   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 6   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 7                                                 NaN
# 8   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 9   Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 10  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 11  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 12                                                NaN
# 13  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
# 14  Ara sınavdan yaklaşık hangi notu bekliyorsun (...
#
#                        LCs/LC11.section1.json answers  \
# 0   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 1   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 6   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 7   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 8   Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 9                                                 NaN
# 10  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 11  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 12  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 13  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
# 14  Thread oluşturmanın 2 temel yöntemi nedir? Thr...
#
#                      Quizzes/Quiz1.ube_1.json answers  \
# 0   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 1   Bil21 1\n \nQuiz\n \n1\n \nSection\n \n1\n \n ...
# 2                                                 NaN
# 3                                                 NaN
# 4   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 5   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 6   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 7   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 8   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 9   Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 10  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 11  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 12  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 13  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
# 14  Bil211 Quiz 1 Section 2\n\nQuizleri uzak siste...
#
#                      Quizzes/Quiz2.ube_1.json answers  \
# 0   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 1   Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 2   Kahve Sipariş Sistemi\n\nBIL 211 - Quiz 2\n\n1...
# 3   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 4   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 5   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 6   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 7   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 8                                                 NaN
# 9   Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 10  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 11  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 12  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 13  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
# 14  Robot Fabrikası\nBIL 211 - Quiz 2\n13 Şubat 20...
#
#                      Quizzes/Quiz3.ube_1.json answers  \
# 0   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 1   Kek Üretim Boru Hattı\n\nBIL 211 - Quiz 3\n\n2...
# 2                                                 NaN
# 3                                                 NaN
# 4   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 5   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 6   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 7   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 8   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 9   Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 10  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 11  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 12  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 13  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
# 14  Envanter Takip Sistemi\nBIL 211 - Quiz 3\n27 Ş...
#
#                      Quizzes/Quiz4.ube_1.json answers
# 0   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 1   Bil211 Quiz 4 Section 1\n\nQuizleri uzak siste...
# 2                                                 NaN
# 3   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 4   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 5   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 6   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 7   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 8   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 9   Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 10  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 11  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 12  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 13  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...
# 14  Bil211 Quiz 4 Section 2\n\nQuizleri uzak siste...

# %%
# Replace NaN values with empty strings
combined_df = combined_df.fillna("")
combined_df_sube_2 = combined_df_sube_2.fillna("")
common_combined_df = common_combined_df.fillna("")

# %%
combined_df = combined_df.reset_index(drop=True)
combined_df_sube_2 = combined_df_sube_2.reset_index(drop=True)

# %%
combined_df.columns
# Out:
# Index(['id', 'Labs/Lab1.ube_1.json answers', 'Labs/Lab2.ube_1.json answers',
#        'Labs/Lab3.ube_1.json answers', 'Labs/Lab4.ube_1.json answers',
#        'LCs/LC1.section1.json answers', 'LCs/LC2.section1.json answers',
#        'LCs/LC3.section1.json answers', 'LCs/LC4.section1.json answers',
#        'LCs/LC5.section1.json answers', 'LCs/LC6.section1.json answers',
#        'LCs/LC7.section1.json answers', 'LCs/LC8.section1.json answers',
#        'LCs/LC9.section1.json answers', 'LCs/LC10.section1.json answers',
#        'LCs/LC11.section1.json answers', 'Quizzes/Quiz1.ube_1.json answers',
#        'Quizzes/Quiz2.ube_1.json answers', 'Quizzes/Quiz3.ube_1.json answers',
#        'Quizzes/Quiz4.ube_1.json answers'],
#       dtype='object')

# %%
# We will merge the columns in combined_df

answers_arr = []
for i in range(len(combined_df)):
    answers = ""
    for column in combined_df.columns:
        if column != "id":
            answers += str(combined_df[column][i]) + " "
    answers_arr.append(answers)

combined_df["answers"] = answers_arr
columns_to_drop = ['Labs/Lab1.ube_1.json answers', 'Labs/Lab2.ube_1.json answers',
       'Labs/Lab3.ube_1.json answers', 'Labs/Lab4.ube_1.json answers',
       'LCs/LC1.section1.json answers', 'LCs/LC2.section1.json answers',
       'LCs/LC3.section1.json answers', 'LCs/LC4.section1.json answers',
       'LCs/LC5.section1.json answers', 'LCs/LC6.section1.json answers',
       'LCs/LC7.section1.json answers', 'LCs/LC8.section1.json answers',
       'LCs/LC9.section1.json answers', 'LCs/LC10.section1.json answers',
       'LCs/LC11.section1.json answers', 'Quizzes/Quiz1.ube_1.json answers',
       'Quizzes/Quiz2.ube_1.json answers', 'Quizzes/Quiz3.ube_1.json answers',
       'Quizzes/Quiz4.ube_1.json answers']
combined_df = combined_df.drop(columns=columns_to_drop)

# %%
combined_df
# Out:
#          id                                            answers
# 0   4380745  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 1   7214465  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 2   9830856  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 3   8435496  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 4   8783086  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 5   4731282  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 6   6202193  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 7   8190737  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 8   7817361  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 9   6897869  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 10  1764665  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 11  6275288   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 12  6194008   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 13  8964453   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 14  3659398   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...

# %%
combined_df_sube_2.columns
# Out:
# Index(['id', 'Labs/Lab1.ube_2.json answers', 'Labs/Lab2.ube_2.json answers',
#        'Labs/Lab3.ube_2.json answers', 'Labs/Lab4.ube_2.json answers',
#        'LCs/LC1.section2.json answers', 'LCs/LC2.section2.json answers',
#        'LCs/LC3.section2.json answers', 'LCs/LC4.section2.json answers',
#        'LCs/LC6.section2.json answers', 'LCs/LC7.section2.json answers',
#        'LCs/LC8.section2.json answers', 'LCs/LC9.section2.json answers',
#        'LCs/LC10.section2.json answers', 'Quizzes/Quiz1.ube_2.json answers',
#        'Quizzes/Quiz2.ube_2.json answers', 'Quizzes/Quiz3.ube_2.json answers',
#        'Quizzes/Quiz4.ube_2.json answers'],
#       dtype='object')

# %%
answers_arr = []
for i in range(len(combined_df_sube_2)):
    answers = ""
    for column in combined_df_sube_2.columns:
        if column != "id":
            answers += str(combined_df_sube_2[column][i]) + " "
    answers_arr.append(answers)

combined_df_sube_2["answers"] = answers_arr
columns_to_drop = ['Labs/Lab1.ube_2.json answers', 'Labs/Lab2.ube_2.json answers',
       'Labs/Lab3.ube_2.json answers', 'Labs/Lab4.ube_2.json answers',
       'LCs/LC1.section2.json answers', 'LCs/LC2.section2.json answers',
       'LCs/LC3.section2.json answers', 'LCs/LC4.section2.json answers',
       'LCs/LC6.section2.json answers', 'LCs/LC7.section2.json answers',
       'LCs/LC8.section2.json answers', 'LCs/LC9.section2.json answers',
       'LCs/LC10.section2.json answers', 'Quizzes/Quiz1.ube_2.json answers',
       'Quizzes/Quiz2.ube_2.json answers', 'Quizzes/Quiz3.ube_2.json answers',
       'Quizzes/Quiz4.ube_2.json answers']
combined_df_sube_2 = combined_df_sube_2.drop(columns=columns_to_drop)

# %%
combined_df_sube_2
# Out:
#          id                                            answers
# 0   6094496  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 1   7732416  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 2   2384475  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 3   2786122  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 4   9367691  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 5   2179244  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 6   6343320  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 7   4275079  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 8   7374887  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 9   6539697  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 10  5902250  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 11  4810237  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 12  4810237  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 13  4540765  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 14  6418019  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 15  4114373  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 16  3963286  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 17  1889298  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 18  6494434  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 19  2103960  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 20  3688139  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 21  9167236  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 22  4856424  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 23  9164612  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 24  5281670   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 25  8862077   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 26  8700334   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...

# %%
common_combined_df.columns
# Out:
# Index(['id', 'Labs/Lab1.ube_1.json answers', 'Labs/Lab2.ube_1.json answers',
#        'Labs/Lab3.ube_1.json answers', 'Labs/Lab4.ube_1.json answers',
#        'LCs/LC1.section1.json answers', 'LCs/LC2.section1.json answers',
#        'LCs/LC3.section1.json answers', 'LCs/LC4.section1.json answers',
#        'LCs/LC5.section1.json answers', 'LCs/LC6.section1.json answers',
#        'LCs/LC7.section1.json answers', 'LCs/LC8.section1.json answers',
#        'LCs/LC9.section1.json answers', 'LCs/LC10.section1.json answers',
#        'LCs/LC11.section1.json answers', 'Quizzes/Quiz1.ube_1.json answers',
#        'Quizzes/Quiz2.ube_1.json answers', 'Quizzes/Quiz3.ube_1.json answers',
#        'Quizzes/Quiz4.ube_1.json answers'],
#       dtype='object')

# %%
answers_arr = []
for i in range(len(common_combined_df)):
    answers = ""
    for column in common_combined_df.columns:
        if column != "id":
            answers += str(common_combined_df[column][i]) + " "
    answers_arr.append(answers)

common_combined_df["answers"] = answers_arr
columns_to_drop = ['Labs/Lab1.ube_1.json answers', 'Labs/Lab2.ube_1.json answers',
       'Labs/Lab3.ube_1.json answers', 'Labs/Lab4.ube_1.json answers',
       'LCs/LC1.section1.json answers', 'LCs/LC2.section1.json answers',
       'LCs/LC3.section1.json answers', 'LCs/LC4.section1.json answers',
       'LCs/LC5.section1.json answers', 'LCs/LC6.section1.json answers',
       'LCs/LC7.section1.json answers', 'LCs/LC8.section1.json answers',
       'LCs/LC9.section1.json answers', 'LCs/LC10.section1.json answers',
       'LCs/LC11.section1.json answers', 'Quizzes/Quiz1.ube_1.json answers',
       'Quizzes/Quiz2.ube_1.json answers', 'Quizzes/Quiz3.ube_1.json answers',
       'Quizzes/Quiz4.ube_1.json answers']
common_combined_df = common_combined_df.drop(columns=columns_to_drop)

# %%
common_combined_df
# Out:
#          id                                            answers
# 0   1280995  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 1   1762204  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 2   2051651  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 3   2112376   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 4   4779274  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 5   5187413  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 6   5361565  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 7   5628146  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 8   6157698  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 9   6429016  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 10  6914659  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 11  8059049  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 12  8857652  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 13  9245287  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 14  9905145  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...

# %%
final_dataset = pd.concat([combined_df,combined_df_sube_2,common_combined_df], ignore_index=True)

# %%
final_dataset
# Out:
#          id                                            answers
# 0   4380745  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 1   7214465  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 2   9830856  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 3   8435496  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 4   8783086  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 5   4731282  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 6   6202193  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 7   8190737  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 8   7817361  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 9   6897869  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 10  1764665  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 11  6275288   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 12  6194008   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 13  8964453   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 14  3659398   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 15  6094496  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 16  7732416  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 17  2384475  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 18  2786122  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 19  9367691  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 20  2179244  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 21  6343320  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 22  4275079  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 23  7374887  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 24  6539697  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 25  5902250  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 26  4810237  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 27  4810237  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 28  4540765  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 29  6418019  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 30  4114373  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 31  3963286  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 32  1889298  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 33  6494434  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 34  2103960  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 35  3688139  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 36  9167236  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 37  4856424  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 38  9164612  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 39  5281670   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 40  8862077   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 41  8700334   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 42  1280995  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 43  1762204  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 44  2051651  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 45  2112376   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 46  4779274  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 47  5187413  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 48  5361565  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 49  5628146  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 50  6157698  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 51  6429016  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 52  6914659  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 53  8059049  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 54  8857652  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 55  9245287  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 56  9905145  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...

# %%
# We need to add the projects to the final_dataset

# %%
project_df = load_json_to_dataframe("Projects/Projects.json")

# %%
project_df
# Out:
#          id                     Projects/Projects.json answers
# 0   8435496  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 1   8964453  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 2   7817361  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 3   6275288  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 4   1762204  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 5   4731282  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 6   1764665  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 7   8783086  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 8   9830856  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 9   4380745  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 10  7214465  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 11  8190737  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 12  3659398  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 13  6897869  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 14  6494434  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 15  6539697  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 16  9245287  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 17  2179244  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 18  1889298  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 19  4810237  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 20  6094496  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 21  6157698  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 22  6418019  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 23  5628146  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 24  8059049  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 25  6914659  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 26  8862077  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 27  4275079  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 28  9905145  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 29  2384475  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 30  5281670  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 31  9164612  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 32  9167236  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 33  2112376  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 34  3688139  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 35  5187413  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 36  7374887  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 37  2103960  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 38  5902250  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 39  1280995  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 40  8857652  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 41  7732416  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 42  4779274  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 43  4114373  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 44  4540765  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 45  5361565  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...
# 46  2786122  Kuş Bakışı Atış Oyunu (Top-Down Shooter)\nBIL ...

# %%
merged_df = final_dataset.merge(project_df, on="id", how="left")

# %%
merged_df["answers"] = merged_df["answers"].fillna("") + " " + merged_df[Projects/Projects.json answers].fillna("")

# %%
merged_df.drop(columns=["Projects/Projects.json answers"],inplace=True)

# %%
final_dataset = merged_df.copy()

# %%
duplicate_ids = final_dataset["id"][final_dataset["id"].duplicated()].unique()
print(duplicate_ids)
# Out:
# ['4810237']

# %%
final_dataset = final_dataset.drop(26)
final_dataset = final_dataset.reset_index(drop=True)
final_dataset
# Out:
#          id                                            answers
# 0   4380745  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 1   7214465  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 2   9830856  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 3   8435496  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 4   8783086  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 5   4731282  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 6   6202193  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 7   8190737  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 8   7817361  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 9   6897869  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 10  1764665  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 11  6275288   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 12  6194008   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 13  8964453   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 14  3659398   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 15  6094496  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 16  7732416  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 17  2384475  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 18  2786122  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 19  9367691  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 20  2179244  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 21  6343320  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 22  4275079  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 23  7374887  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 24  6539697  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 25  5902250  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 26  4810237  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 27  4540765  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 28  6418019  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 29  4114373  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 30  3963286  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 31  1889298  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 32  6494434  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 33  2103960  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 34  3688139  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 35  9167236  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 36  4856424  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 37  9164612  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 38  5281670   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 39  8862077   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 40  8700334   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 41  1280995  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 42  1762204  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 43  2051651  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 44  2112376   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 45  4779274  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 46  5187413  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 47  5361565  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 48  5628146  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 49  6157698  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 50  6429016  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 51  6914659  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 52  8059049  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 53  8857652  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 54  9245287  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 55  9905145  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...

# %%
train_id_proper = []
for item in train_ids:
    train_id_proper.append(str(item))
test_id_proper = []
for item in test_ids:
    test_id_proper.append(str(item))

# %%
train_df = final_dataset[final_dataset['id'].isin(train_id_proper)].reset_index(drop=True)
test_df = final_dataset[final_dataset['id'].isin(test_id_proper)].reset_index(drop=True)

# %%
train_df
# Out:
#          id                                            answers
# 0   7214465  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 1   9830856  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 2   8435496  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 3   8783086  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 4   4731282  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 5   6202193  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 6   7817361  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 7   6897869  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 8   1764665  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 9   6275288   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 10  6194008   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 11  3659398   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 12  6094496  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 13  7732416  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 14  2384475  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 15  2786122  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 16  9367691  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 17  2179244  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 18  6343320  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 19  4275079  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 20  7374887  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 21  6539697  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 22  5902250  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 23  4810237  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 24  3963286  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 25  1889298  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 26  6494434  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 27  2103960  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 28  3688139  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 29  9167236  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 30  4856424  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 31  9164612  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 32  8862077   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 33  8700334   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 34  1762204  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 35  2112376   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 36  5361565  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 37  5628146  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 38  6157698  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 39  6429016  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 40  8059049  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 41  8857652  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 42  9245287  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 43  9905145  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...

# %%
test_df
# Out:
#          id                                            answers
# 0   4380745  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 1   8190737  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 2   8964453   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 3   2384475  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 4   4540765  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 5   6418019  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 6   4114373  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 7   5281670   Müzik Çalar Simülasyonu\n\nBIL 211 - Laboratu...
# 8   1280995  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 9   2051651  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 10  4779274  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 11  5187413  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...
# 12  6914659  Recursion\n \n \n1)\n \nCollatz\n \nproblemi.\...

# %%
for item in test_id_proper:
    if item not in test_df["id"].values:
        print(item)
# Out:
# 5803666
# 9860471
# 8154684

# %%
for item in train_id_proper:
    if item not in train_df["id"].values:
        print(item)
# Out:
# 4819615

# %%
import re

def clean_text(text):
    # Normalize whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    # Lowercase (optional)
    text = text.lower()
    return text

train_df["answers"] = train_df["answers"].fillna("").apply(clean_text)
test_df["answers"] = test_df["answers"].fillna("").apply(clean_text)

# %%
train_df.to_csv("train_dataset.csv",index=False)
test_df.to_csv("test_dataset.csv",index=False)

# %%
def mark_code_blocks_inline(text):
    # Regex pattern to match Java code blocks heuristically
    # This looks for a sequence with typical Java code patterns
    code_pattern = re.compile(
        r'((?:public|class|static|void|int|String|if|else|for|while|return|import|package|new|try|catch)[^.;{}]*[;{}])',
        flags=re.IGNORECASE
    )

    def replacer(match):
        code_snippet = match.group(0).strip()
        return f"[CODE]{code_snippet}[/CODE]"

    # Replace all code-like snippets with wrapped version
    result = code_pattern.sub(replacer, text)
    return result

# %%
train_df["answers"] = train_df["answers"].apply(mark_code_blocks_inline)
test_df["answers"] = test_df["answers"].apply(mark_code_blocks_inline)

# %%
train_df.to_csv("train_dataset_coded.csv",index=False)
test_df.to_csv("test_dataset_coded.csv",index=False)
